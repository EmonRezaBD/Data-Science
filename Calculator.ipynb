# %% [markdown]
# <a href="https://colab.research.google.com/github/EmonRezaBD/Data-Science/blob/master/Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('1. Addition \n2.Subtraction')
option = int(input('Give your option: '))
if option==1:
   x = int(input('Enter 1st num: '))
   y = int(input('Enter sec num: '))
   print('Summation of ',x,'and ',y,'is: ',x+y)
elif option==2:
   x = int(input('Enter 1st num: '))
   y = int(input('Enter sec num: '))
   print('Subtraction of ',x,'and ',y,'is: ',x-y)
else:
  print('ok')
# Out:
# 1. Addition
# 2.Subtraction
# Give your option: 2
# Enter 1st num: 3
# Enter sec num: 2
# Subtraction of  3 and  2 is:  1
